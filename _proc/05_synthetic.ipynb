# %% [raw]
# ---
# description: A probabilistic hot water usage model and simulator for use in residential
#   energy management
# output-file: synthetic.html
# title: Synthetic residential hot water usage model
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# https://www.sciencedirect.com/science/article/pii/S0378778821000116

# %% [markdown]
# Check the flow data that we use in comparison to the synthetic data. This code is from thier paper.

# %%
#| echo: false
#| output: asis
show_doc(save_profiles)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L519){target="_blank" style="float:right; font-size:smaller"}
#
# ### save_profiles
#
# >      save_profiles (profile_data, ewh_id)

# %%
#| echo: false
#| output: asis
show_doc(get_profile)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L498){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_profile
#
# >      get_profile (event_starts, event_volumes, event_flow_rates)

# %%
#| echo: false
#| output: asis
show_doc(get_profile_data)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L479){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_profile_data
#
# >      get_profile_data (event_data)

# %%
#| echo: false
#| output: asis
show_doc(pick_nominal_event)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L465){target="_blank" style="float:right; font-size:smaller"}
#
# ### pick_nominal_event
#
# >      pick_nominal_event (cluster_data, time_cluster)

# %%
#| echo: false
#| output: asis
show_doc(pick_random_event)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L453){target="_blank" style="float:right; font-size:smaller"}
#
# ### pick_random_event
#
# >      pick_random_event (cluster_data, time_cluster)

# %%
#| echo: false
#| output: asis
show_doc(combine_volumes)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L445){target="_blank" style="float:right; font-size:smaller"}
#
# ### combine_volumes
#
# >      combine_volumes (event_volumes, volume_index)

# %%
#| echo: false
#| output: asis
show_doc(pick_from_fitted_gauss)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L439){target="_blank" style="float:right; font-size:smaller"}
#
# ### pick_from_fitted_gauss
#
# >      pick_from_fitted_gauss (covariance, mean)

# %%
#| echo: false
#| output: asis
show_doc(get_events)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L410){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_events
#
# >      get_events (cluster_data, day_amount)

# %%
#| echo: false
#| output: asis
show_doc(get_event_data)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L395){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_event_data
#
# >      get_event_data (cluster_data)

# %%
#| echo: false
#| output: asis
show_doc(cluster_2)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L370){target="_blank" style="float:right; font-size:smaller"}
#
# ### cluster_2
#
# >      cluster_2 (cluster_amount, cluster_data, cluster_type)

# %%
#| echo: false
#| output: asis
show_doc(cluster)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L345){target="_blank" style="float:right; font-size:smaller"}
#
# ### cluster
#
# >      cluster (cluster_amount, cluster_data, cluster_type)

# %%
#| echo: false
#| output: asis
show_doc(list_to_coordinates)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L342){target="_blank" style="float:right; font-size:smaller"}
#
# ### list_to_coordinates
#
# >      list_to_coordinates (list_1, list_2)

# %%
#| echo: false
#| output: asis
show_doc(elbow_method_2)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L317){target="_blank" style="float:right; font-size:smaller"}
#
# ### elbow_method_2
#
# >      elbow_method_2 (cluster_data, max_clusters, cluster_type,
# >                      elbow_tolerance)

# %%
#| echo: false
#| output: asis
show_doc(elbow_method)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L292){target="_blank" style="float:right; font-size:smaller"}
#
# ### elbow_method
#
# >      elbow_method (cluster_data, max_clusters, cluster_type, elbow_tolerance)

# %%
#| echo: false
#| output: asis
show_doc(pick_from_gauss)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L281){target="_blank" style="float:right; font-size:smaller"}
#
# ### pick_from_gauss
#
# >      pick_from_gauss (data, time_bins)

# %%
#| echo: false
#| output: asis
show_doc(get_gauss)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L261){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_gauss
#
# >      get_gauss (data)

# %%
#| echo: false
#| output: asis
show_doc(get_centroid)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L241){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_centroid
#
# >      get_centroid (time_boundaries, flow_rates)

# %%
#| echo: false
#| output: asis
show_doc(get_cluster_probability)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L216){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_cluster_probability
#
# >      get_cluster_probability (day_type, flow_rates, flow_boundaries,
# >                               volume_boundaries, time_boundaries)

# %%
#| echo: false
#| output: asis
show_doc(get_event_parameters)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L201){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_event_parameters
#
# >      get_event_parameters (flow_rates, time_boundaries)

# %%
#| echo: false
#| output: asis
show_doc(get_clusters)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L143){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_clusters
#
# >      get_clusters (cluster_data, temp_cluster_data, day_type, flow_data)

# %%
#| echo: false
#| output: asis
show_doc(get_cluster_data)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L102){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_cluster_data
#
# >      get_cluster_data (flow_data)

# %%
#| echo: false
#| output: asis
show_doc(find_flow)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L92){target="_blank" style="float:right; font-size:smaller"}
#
# ### find_flow
#
# >      find_flow (source_data)

# %%
#| echo: false
#| output: asis
show_doc(get_flow_data)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L72){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_flow_data
#
# >      get_flow_data (source_data)

# %%
#| echo: false
#| output: asis
show_doc(get_source_data)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/synthetic.py#L65){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_source_data
#
# >      get_source_data (ewh_id)

# %%
source_data = {}
flow_data = {}
cluster_data = {}
event_data = {}
profile_data = {}
for q in EWH_RANGE:
    source_data[q] = get_source_data(q)
    flow_data[q] = {}
    cluster_data[q] = {}
    event_data[q] = {}
    profile_data[q] = {}
    for s in range(len(seasons)):
        flow_data[q][seasons[s]] = get_flow_data(source_data[q][seasons[s]])
        cluster_data[q][seasons[s]] = get_cluster_data(flow_data[q][seasons[s]])
        event_data[q][seasons[s]] = get_event_data(cluster_data[q][seasons[s]])
        profile_data[q][seasons[s]] = get_profile_data(event_data[q][seasons[s]])

# %%
flow = load_demand(path = Path('../data/drawprofiles'),bed=2,unit=3)

# %%
df = flow['2020-01-01':'2020-01-07'].to_frame().assign(synthetic=profile_data[0][seasons[3]]['differentiated_days'])

# %%
df.head()
# Out:
#                      2_3  synthetic
# timestamp
# 2020-01-01 00:00:00  0.0        0.0
# 2020-01-01 00:01:00  0.0        0.0
# 2020-01-01 00:02:00  0.0        0.0
# 2020-01-01 00:03:00  0.0        0.0
# 2020-01-01 00:04:00  0.0        0.0

# %%
fig, ax = plt.subplots(nrows = 2 ,figsize=(12,6), sharex=True)
ax[0].plot(df.synthetic, label='Synthetic Demand')
ax[0].plot(df.loc[:,'2_3']*60000, label='BEopt Demand')
ax[0].set_ylabel('Flow (litre/min)')
ax[0].legend()
ax[1].plot(df.synthetic.cumsum(), label='Synthetic Demand')
ax[1].plot((df.loc[:,'2_3']*60000).cumsum(), label='BEopt Demand')
ax[1].set_ylabel('Cumulative Flow (litres)')
ax[1].set_xlabel('Time')
ax[1].legend()
fig.suptitle('Flow data comparison')
# flow['2020-01-01':'2020-01-07'].plot()
# ax.plot(flow['2020-01-01':'2020-01-07'])
# Out:
# Text(0.5, 0.98, 'Flow data comparison')

# %% [markdown]
# Other potential demand profiles
# https://uknowledge.uky.edu/cgi/viewcontent.cgi?article=1082&context=bae_etds
