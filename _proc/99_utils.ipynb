# %% [raw]
# ---
# output-file: utils.html
# title: Utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(get_season)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/utils.py#L21){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_season
#
# >      get_season (date)

# %%
#| echo: false
#| output: asis
show_doc(series_timestamps)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/utils.py#L33){target="_blank" style="float:right; font-size:smaller"}
#
# ### series_timestamps
#
# >      series_timestamps (ser)

# %%
#| echo: false
#| output: asis
show_doc(plot_sim)
# Out:
# ---
#
# [source](https://github.com/CJP123/cylinder/blob/main/cylinder/utils.py#L57){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_sim
#
# >      plot_sim (strategy, df)
